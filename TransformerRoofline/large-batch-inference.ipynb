# %%
import roofline as rf 
roofline = rf.TransformerRoofline('hardware_models.json')

new_hard = {"Name": "8MI300X", 
            "Type": "Homo",
            "PRF": {"hard":"MI300X", "quant":8}, 
            "GNR-PRJ": {"hard":"MI300X", "quant":8}, 
            "GNR-ACT": {"hard":"MI300X", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "2A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":2}, 
            "GNR-PRJ": {"hard":"A100", "quant":2}, 
            "GNR-ACT": {"hard":"A100", "quant":2}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "1A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":1}, 
            "GNR-PRJ": {"hard":"A100", "quant":1}, 
            "GNR-ACT": {"hard":"A100", "quant":1}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"A100", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10", 
            "Type": "Homo",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"A10", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10", 
            "Type": "Homo",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"A10", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100", 
            "Type": "Homo",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"V100", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"A100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100", 
            "Type": "Homo",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"V100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100", 
            "Type": "Homo",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"H100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8PPU", 
            "Type": "Homo",
            "PRF": {"hard":"PPU", "quant":8}, 
            "GNR-PRJ": {"hard":"PPU", "quant":8}, 
            "GNR-ACT": {"hard":"PPU", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "4A100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)


new_hard = {"Name": "8A100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "8A100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "8THRIVE++", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++", "quant":8}, 
            "GNR-PRJ": {"hard":"THRIVE++", "quant":8}, 
            "GNR-ACT": {"hard":"THRIVE++", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4THRIVE++MCM", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++MCM", "quant":4}, 
            "GNR-PRJ": {"hard":"THRIVE++MCM", "quant":4}, 
            "GNR-ACT": {"hard":"THRIVE++MCM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8THRIVE++MCM", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++MCM", "quant":8}, 
            "GNR-PRJ": {"hard":"THRIVE++MCM", "quant":8}, 
            "GNR-ACT": {"hard":"THRIVE++MCM", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
# benchmark: M6-13B, GPT3.5-175B, Falcon, LLaMa
# seq: 2K, 8K, 32K
# batch: 2, 8, 32

#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"])
#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[2048, 8192, 32768], Model=["GPT3.5", "LLaMa", "Falcon"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"])
#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.0000001], Batchsize=["max"], Max_Token=[32768], Model=["Falcon"], Hardware=["1A100", "2A100", "4A100", "8A100", "4V100", "8V100", "4A10", "8A10"], Sparse = ["default"])
#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.0000001], Batchsize=[64, 128, "max"], Max_Token=[32768], Model=["GPT3.5-mq"], Hardware=["8A100"], Sparse = ["default"])
roofline.List_Timebreakdown_Ratio(Ratio_P=[0.0000001], Batchsize=[4, 16, 64, 128, "max"], Max_Token=[32768], Model=["M6-50B-mq", "Falcon", "GPT3.5-mq"], Hardware=["4A100", "8A100"], Sparse = ["default"])
# Out:
# *******List_Timebreakdown*******
# Model   Hardware            Pipe Ratio_P Batch     Seq    | FPRT(ms)       L(ms/tok)      Thr(quary/s)   SLO         ¢/k-token   | BatchTime-Ttl  | Comp(%)     Comm(%)     | P(%)        GP(%)       GA(%)       | Comp-P(%)   Comm-P(%)   Comp-GP(%)  Comm-GP(%)  Comp-GA(%)  Comm-GA(%)  | Util-Ttl    Util-P      Util-GP     Util-GA
# M6-50B-mq4A100               1    0.00    4         32768  | 14.38          13.52          0.01           99.99000%   ¢0.946779   |        442.91  | 88.51%      11.49%      | 0.00%       98.19%      1.81%       | 0.00%       0.00%       86.70%      11.49%      1.81%       0.00%       | 2.96%       0.01%       2.26%       41.03%
# M6-50B-mq4A100               1    0.00    16        32768  | 14.35          14.57          0.03           99.96000%   ¢0.255169   |        477.48  | 87.13%      12.87%      | 0.00%       93.30%      6.70%       | 0.00%       0.00%       80.42%      12.87%      6.70%       0.00%       | 11.00%      0.03%       8.84%       41.03%
# M6-50B-mq4A100               1    0.00    64        32768  | 14.39          19.73          0.10           99.84000%   ¢0.0863683  |        646.46  | 79.20%      20.80%      | 0.00%       80.20%      19.80%      | 0.00%       0.00%       59.40%      20.80%      19.80%      0.00%       | 32.49%      0.11%       30.39%      41.03%
# Falcon  8A100               1    0.00    64        32768  | 10.30          10.77          0.18           99.84000%   ¢0.0888131  |        353.04  | 59.48%      40.52%      | 0.00%       91.50%      8.50%       | 0.00%       0.00%       50.99%      40.51%      8.50%       0.00%       | 27.89%      0.07%       22.86%      82.05%
# Falcon  8A100               1    0.00    128       32768  | 10.25          12.92          0.30           99.61600%   ¢0.0532447  |        423.31  | 56.70%      43.30%      | 0.00%       85.82%      14.17%      | 0.00%       0.00%       42.52%      43.30%      14.17%      0.00%       | 46.52%      0.14%       40.65%      82.05%
# Comm BW bound: 2.10MB
# Falcon  8A100               1    0.00    max(1024) 32768  | 10.67          67.70          0.46           96.66900%   ¢0.0348785  |       2218.34  | 74.90%      25.10%      | 0.00%       78.36%      21.64%      | 0.00%       0.00%       53.26%      25.10%      21.64%      0.00%       | 71.02%      1.11%       67.97%      82.05%
# Comm BW bound: 16.78MB
# GPT3.5-mq8A100               1    0.00    4         32768  | 27.39          24.28          0.01           99.99000%   ¢3.20264    |        795.68  | 82.20%      17.80%      | 0.00%       99.24%      0.75%       | 0.00%       0.00%       81.44%      17.80%      0.75%       0.00%       | 2.55%       0.01%       2.10%       61.54%
# GPT3.5-mq8A100               1    0.00    16        32768  | 27.39          26.48          0.02           99.96000%   ¢0.873296   |        867.86  | 77.43%      22.57%      | 0.00%       97.23%      2.77%       | 0.00%       0.00%       74.67%      22.57%      2.77%       0.00%       | 9.36%       0.02%       7.88%       61.54%
# GPT3.5-mq8A100               1    0.00    64        32768  | 27.44          30.67          0.06           99.84000%   ¢0.252845   |       1005.09  | 74.03%      25.97%      | 0.00%       90.45%      9.55%       | 0.00%       0.00%       64.47%      25.97%      9.55%       0.00%       | 32.33%      0.10%       29.24%      61.54%
# GPT3.5-mq8A100               1    0.00    128       32768  | 27.39          36.91          0.11           99.68000%   ¢0.152139   |       1209.54  | 69.45%      30.55%      | 0.00%       84.12%      15.87%      | 0.00%       0.00%       53.57%      30.55%      15.87%      0.00%       | 53.73%      0.19%       52.25%      61.54%
# Comm BW bound: 3.15MB
# GPT3.5-mq8A100               1    0.00    max(256)  32768  | 27.71          62.05          0.13           99.36000%   ¢0.127867   |       2033.15  | 71.19%      28.81%      | 0.00%       81.11%      18.89%      | 0.00%       0.00%       52.30%      28.81%      18.89%      0.00%       | 63.93%      0.38%       64.48%      61.54%
# Comm BW bound: 6.29MB

# %%
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.0000001], Batchsize=[16, 64, 128, 256], Max_Token=[32768], Model=["M6-50B-mq"], Hardware=["4A100", "8A100"], Latency_QPS="Qps", precentage=True, Pipeline_Stage = 1, figsize = [6, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.0000001], Batchsize=[16, 64, 128, 256], Max_Token=[32768], Model=["GPT3.5-mq"], Hardware=["4A100", "8A100"], Latency_QPS="Qps", precentage=True, Pipeline_Stage = 1, figsize = [6, 4])
