# %%
import roofline as rf 
roofline = rf.TransformerRoofline('hardware_models.json')

new_hard = {"Name": "8MI300X", 
            "Type": "Homo",
            "PRF": {"hard":"MI300X", "quant":8}, 
            "GNR-PRJ": {"hard":"MI300X", "quant":8}, 
            "GNR-ACT": {"hard":"MI300X", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"A100", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10", 
            "Type": "Homo",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"A10", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10", 
            "Type": "Homo",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"A10", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100", 
            "Type": "Homo",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"V100", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"A100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100", 
            "Type": "Homo",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"V100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100", 
            "Type": "Homo",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"H100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8PPU", 
            "Type": "Homo",
            "PRF": {"hard":"PPU", "quant":8}, 
            "GNR-PRJ": {"hard":"PPU", "quant":8}, 
            "GNR-ACT": {"hard":"PPU", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "4A100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)


new_hard = {"Name": "8A100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100+8G6", 
            "Type": "Hete",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":8}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100+4G6", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"G6AiM", "quant":4}, 
            "Server": 2,
            "Rack_Unit": 8,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "8A100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":4}, 
            "GNR-PRJ": {"hard":"A100", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4V100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":4}, 
            "GNR-PRJ": {"hard":"V100", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4A10+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":4}, 
            "GNR-PRJ": {"hard":"A10", "quant":4}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A100+1TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":16}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8A10+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"A10", "quant":8}, 
            "GNR-PRJ": {"hard":"A10", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100+2TPIM", 
            "Type": "Hete",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"CXLv0", "quant":32}, 
            "Server": 2,
            "Rack_Unit": 6,
            "Assign": "PRF+GNR-PRJ, GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
new_hard = {"Name": "8THRIVE++", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++", "quant":8}, 
            "GNR-PRJ": {"hard":"THRIVE++", "quant":8}, 
            "GNR-ACT": {"hard":"THRIVE++", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "4THRIVE++MCM", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++MCM", "quant":4}, 
            "GNR-PRJ": {"hard":"THRIVE++MCM", "quant":4}, 
            "GNR-ACT": {"hard":"THRIVE++MCM", "quant":4}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8THRIVE++MCM", 
            "Type": "Homo",
            "PRF": {"hard":"THRIVE++MCM", "quant":8}, 
            "GNR-PRJ": {"hard":"THRIVE++MCM", "quant":8}, 
            "GNR-ACT": {"hard":"THRIVE++MCM", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

# %%
# benchmark: M6-13B, GPT3.5-175B, Falcon, LLaMa
# seq: 2K, 8K, 32K
# batch: 2, 8, 32

#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"])
#roofline.List_Timebreakdown_Ratio(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[2048, 8192, 32768], Model=["GPT3.5", "LLaMa", "Falcon"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"])

# %%
################## M6-13B study ##################

# batch impact, 4K/4K
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16, "Max"], Max_Token=[8192], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16, "Max"], Max_Token=[8192], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])

# seq impact, batch = 4

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])

# seq impact, batch = max

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=["Max"], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=["Max"], Max_Token=[2048, 8192, 32768], Model=["M6-13B-8K"], Hardware=["4A100", "4A100+4G6", "4A100+1TPIM", "4THRIVE++MCM"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])

# %%
################## Various model study ##################
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["LLaMa"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["Falcon"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)


roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["LLaMa"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["Falcon"], Hardware=["8A100", "8A100+8G6", "8A100+2TPIM", "8THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)

# %%
################## THRIVE++ study ##################
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["LLaMa"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["Falcon"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)


roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["LLaMa"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["Falcon"], Hardware=["8PPU", "8A100", "8H100", "8MI300X", "8THRIVE++MCM", "4THRIVE++MCM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [5, 4], show_cost = True)

# %%
################## Exploration ##################

# does A10 make sense
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, 8, "Max"], Max_Token=[8192], Model=["M6-13B-8K"], Hardware=["4A100", "4A10", "4A100+4G6", "4A10+4G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8A100", "8A10", "8A100+8G6", "8A10+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)

# does 16x G6 make sense
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6", "8A100+4G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6", "8A100+4G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)

# does H100 performs better

#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8V100", "8V100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8V100", "8V100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8A100", "8A100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[8192], Model=["GPT3.5"], Hardware=["8H100", "8H100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[2, "Max"], Max_Token=[32768], Model=["GPT3.5"], Hardware=["8H100", "8H100+8G6"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4], show_cost = True)
