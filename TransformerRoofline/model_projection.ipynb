# %%
import roofline as rf 
roofline = rf.TransformerRoofline('hardware_models.json')

new_hard = {"Name": "8A100", 
            "Type": "Homo",
            "PRF": {"hard":"A100", "quant":8}, 
            "GNR-PRJ": {"hard":"A100", "quant":8}, 
            "GNR-ACT": {"hard":"A100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8V100", 
            "Type": "Homo",
            "PRF": {"hard":"V100", "quant":8}, 
            "GNR-PRJ": {"hard":"V100", "quant":8}, 
            "GNR-ACT": {"hard":"V100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8H100", 
            "Type": "Homo",
            "PRF": {"hard":"H100", "quant":8}, 
            "GNR-PRJ": {"hard":"H100", "quant":8}, 
            "GNR-ACT": {"hard":"H100", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

new_hard = {"Name": "8PPU", 
            "Type": "Homo",
            "PRF": {"hard":"PPU", "quant":8}, 
            "GNR-PRJ": {"hard":"PPU", "quant":8}, 
            "GNR-ACT": {"hard":"PPU", "quant":8}, 
            "Server": 1,
            "Rack_Unit": 4,
            "Assign": "PRF+GNR-PRJ+GNR-ACT"}
roofline.Add_Comb_Hardware(new_hard)

#roofline.List_All_Hardware()
#roofline.List_Timebreakdown(Ratio_P=[0.25], Batchsize=[4, 32], Max_Token=[4096], Model=["GPT3.5"], Hardware=["8A100", "8A100+1TDIMM"])
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.25], Batchsize=[8, 16, 32], Max_Token=[2048], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100", "8A100+1TDIMM"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [2.4, 2.8])
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.25], Batchsize=[32], Max_Token=[2048, 4096, 8096, 16384], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100", "8A100+1TDIMM"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1)

# %%
# page-15 
# future LLM (1/3), larger model

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[2048], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[2048], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[8096], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[8096], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])

#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[2048], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[2048], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[8096], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
#roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16], Max_Token=[8096], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])

# %%
# page-16
# future LLM (2/3), larger seq

roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4], Max_Token=[2048, 32768], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4], Max_Token=[2048, 32768], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4], Max_Token=[2048, 32768], Model=["M6-50B"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=True, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4], Max_Token=[2048, 32768], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Qps", precentage=True, Pipeline_Stage = 1, figsize = [3, 4])

# %%
# page-17
# multi-query and parallel FFN
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[16], Max_Token=[2048, 32768], Model=["GPT3.5"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[16], Max_Token=[2048, 32768], Model=["Falcon"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[16], Max_Token=[2048, 32768], Model=["Palm"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4, 16, 64], Max_Token=[32768], Model=["Palm"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
# roofline.Draw_token_per_second_breakdown(Ratio_P=[0.5], Batchsize=[4], Max_Token=[2048, 32768], Model=["Palm"], Hardware=["8V100", "8A100", "8PPU", "8H100"], Latency_QPS="Latency", precentage=False, Pipeline_Stage = 1, figsize = [3, 4])
